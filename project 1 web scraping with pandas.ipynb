# %%
import pandas as pd

# %% [markdown]
# # 1. Read a .csv from a URL with pandas

# %% [markdown]
# ### Traget website : 'https://www.football-data.co.uk/mmz4281/2526/E0.csv'

# %%
# reading 1 csv file from the website 
df_Premir26 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

# %%
# show data frame
df_Premir26.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  home_goals  away_goals  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth           4           2
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle           0           0
# 2  E0  16/08/2025  15:00     Brighton       Fulham           1           1
# 3  E0  16/08/2025  15:00   Sunderland     West Ham           3           0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley           3           0
#
#   FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0   H     1     0  ...     2.03     1.78   2.07   1.85     2.03     1.88
# 1   D     0     0  ...     2.05     1.80   2.02   1.89     2.06     1.80
# 2   D     0     0  ...     1.83     2.03   1.93   2.00     1.84     2.03
# 3   H     0     0  ...     1.95     1.90   1.97   1.95     1.95     1.94
# 4   H     1     0  ...     1.98     1.88   1.99   1.93     1.98     1.91
#
#    AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# ...

# %%
# rename the columns 
df_Premir26.rename(columns={'FTHG': 'home_goals',
                            'FTAG': 'away_goals'},inplace =True)

# %%
# show dataframe
df_Premir26
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00       Brighton       Fulham           1
# 3    E0  16/08/2025  15:00     Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00      Tottenham      Burnley           3
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa           1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth           1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea           2
# 378  E0  24/05/2026  16:00      Tottenham      Everton           1
# 379  E0  24/05/2026  16:00       West Ham        Leeds           3
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %% [markdown]
# ## 2. Read .csv from multiple URLs with pandas

# %% [markdown]
# ### Link : root + season + league

# %% [markdown]
# • https://www.football-data.co.uk/mmz4281/2526/E0.csv
# •https://www.football-data.co.uk/mmz4281/2526/E1.csv

# %%
# link structure 
'https://www.football-data.co.uk/mmz4281' + '2526' + '/' + 'E1' + '.csv'
# Out:
# 'https://www.football-data.co.uk/mmz42812526/E1.csv'

# %%
# create a root varabile 
root = 'https://www.football-data.co.uk/mmz4281/'

# %% [markdown]
# # 2.1 multiple leagues

# %% [markdown]
# •  https://www.football-data.co.uk/mmz4281/2526/E0.csv
# •  https://www.football-data.co.uk/mmz4281/2526/E1.csv
# •  https://www.football-data.co.uk/mmz4281/2526/E2.csv
# •  https://www.football-data.co.uk/mmz4281/2526/E3.csv
# •  https://www.football-data.co.uk/mmz4281/2526/EC.csv

# %%
# creating list of leagues 
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
# loop thorugh leagues, read multiple .csv and append it into the list
for league in leagues:
    df = pd.read_csv(root + '2526' + '/' + league + '.csv', encoding='unicode_escape')
    frames.append(df)

# %%
# length of frame
len(frames)
# Out:
# 5

# %%
# show 1st, 2nd, 3rd elements
frames[4]
# Out:
#     ï»¿Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0       EC  09/08/2025  15:00      Altrincham       Aldershot     3     2   H
# 1       EC  09/08/2025  15:00    Boreham Wood        Rochdale     0     2   A
# 2       EC  09/08/2025  15:00   Brackley Town       Eastleigh     1     0   H
# 3       EC  09/08/2025  15:00  Braintree Town         Halifax     3     0   H
# 4       EC  09/08/2025  15:00       Gateshead        Southend     0     3   A
# ..     ...         ...    ...             ...             ...   ...   ...  ..
# 547     EC  25/04/2026  12:30      Scunthorpe       Eastleigh     0     1   A
# 548     EC  25/04/2026  12:30        Southend      Wealdstone     2     1   H
# 549     EC  25/04/2026  12:30        Tamworth  Braintree Town     5     1   H
# 550     EC  25/04/2026  12:30          Woking         Halifax     0     1   A
# 551     EC  25/04/2026  12:30          Yeovil        Solihull     1     4   A
#
# ...

# %% [markdown]
# # 2.2 Multiple season

# %%
for season in range (15,26):
    print(str(season) + str(season+1))
# Out:
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021
# 2122
# 2223
# 2324
# 2425
# 2526

# %%
# creating list of leagues
leagues = ['E0','E2', 'E3']
frames = []
# loop through range of seasons and insert new columns
for league in leagues:
    for season in range(15,26):
        df = pd.read_csv(root + str(season) + str(season+1) + '/' + league + '.csv')
        df.insert(1, 'season',season)
        frames.append(df)

# %%
# total frame (11 seasons x 3 leagues )
len(frames)
# Out:
# 33

# %%
# so 1 st and last element (new season columns was create)
frames[0]
# Out:
#     Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
# 1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
# 2    E0      15  08/08/2015      Everton      Watford     2     2   D     0
# 3    E0      15  08/08/2015    Leicester   Sunderland     4     2   H     3
# 4    E0      15  08/08/2015   Man United    Tottenham     1     0   H     1
# ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
# 375  E0      15  15/05/2016        Stoke     West Ham     2     1   H     0
# 376  E0      15  15/05/2016      Swansea     Man City     1     1   D     1
# 377  E0      15  15/05/2016      Watford   Sunderland     2     2   D     0
# 378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
# 379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
# ...

# %% [markdown]
# # 3. Organize All the data in a dictionary

# %%
# Create a dictionary with original name of league as key
dict_countries = {'spanish La Liga': 'SP1', 'Spanish Segunda Division' : 'SP2',
                  'German Bundesliga':'D1',
                  'English premer leaggue':'E0',
                  'English league 1':'E2',
                  'English league 2':'E3'}

# %%
# get a dictionary element 
dict_countries['spanish La Liga']
# Out:
# 'SP1'

# %%
for league in dict_countries:
    print(dict_countries[league])
# Out:
# SP1
# SP2
# D1
# E0
# E2
# E3

# %%
dict_historical_data = {}

# creating list of leagues
for league in dict_countries:
    for season in range(15,26):
        df = pd.read_csv(root + str(season) + str(season+1) + '/' + dict_countries[league] + '.csv')
        df.insert(1, 'season',season)
        frames.append(df)
    df_concat = pd.concat(frames)
    dict_historical_data[league] = df_concat

# %%
# show dataframe inside dict_historcal_data 
dict_historical_data.keys()
# Out:
# dict_keys(['spanish La Liga', 'Spanish Segunda Division', 'German Bundesliga', 'English premer leaggue', 'English league 1', 'English league 2'])

# %%
# show dataframe inside dict_historcal_data 
dict_historical_data['spanish La Liga']
# Out:
#      Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0      15  08/08/2015  Bournemouth  Aston Villa   0.0   1.0   A   0.0
# 1     E0      15  08/08/2015      Chelsea      Swansea   2.0   2.0   D   2.0
# 2     E0      15  08/08/2015      Everton      Watford   2.0   2.0   D   0.0
# 3     E0      15  08/08/2015    Leicester   Sunderland   4.0   2.0   H   3.0
# 4     E0      15  08/08/2015   Man United    Tottenham   1.0   0.0   H   1.0
# ..   ...     ...         ...          ...          ...   ...   ...  ..   ...
# 375  SP1      25  23/05/2026       Girona        Elche   1.0   1.0   D   0.0
# 376  SP1      25  23/05/2026     Mallorca       Oviedo   3.0   0.0   H   1.0
# 377  SP1      25  23/05/2026  Real Madrid   Ath Bilbao   4.0   2.0   H   2.0
# 378  SP1      25  23/05/2026     Valencia    Barcelona   3.0   1.0   H   0.0
# 379  SP1      25  24/05/2026   Villarreal   Ath Madrid   5.0   1.0   H   4.0
#
# ...
